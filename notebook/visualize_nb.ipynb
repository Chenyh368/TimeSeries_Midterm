# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

os.chdir('/home/cyh/Code/ts_midterm')

# %%
# Test set result
exp_name = 'weather_96_96_Autoformer_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_ts0.7_0'
preds = np.load(os.path.join('./results',exp_name, 'pred.npy'))
true = np.load(os.path.join('./results',exp_name, 'true.npy'))

# %%
preds.shape
# Out:
# (10432, 96, 21)

# %%
preds = preds[:,:,-1]

# %%
true = true[:,:,-1]

# %%
preds = preds.reshape(-1)

# %%
preds
# Out:
# array([ 0.31730235,  0.15435499,  0.15727702, ..., -0.03398298,
#        -0.05716143,  0.01723909], dtype=float32)

# %%
true = true.reshape(-1)

# %%
true.shape
# Out:
# (1001472,)

# %%
preds.shape
# Out:
# (1001472,)

# %%
plt.figure(dpi=100)
plt.plot(true, label='GroundTruth', linewidth=0.5)
# plt.scatter(list(range(len(true))),true, label='GroundTruth')
if preds is not None:
    plt.plot(preds, label='Prediction', linewidth=0.5)
    # plt.scatter(list(range(len(true))),preds, label='Prediction')
plt.legend()
